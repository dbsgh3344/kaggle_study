# %% [markdown]
# ## getcontrolgroup 개수 확인
# - control group 들은 event_contents가 nan이다.

# %%
gcg = train.loc[train['event']==5,'event_contents'].value_counts()

# %%
gcg
# Out:
# Series([], Name: event_contents, dtype: int64)

# %%
train[train['event']==5]
# Out:
#           game_id  winner  time  player  species  event event_contents
# 100           0.0     1.0     1     0.0      0.0    5.0            NaN
# 135           0.0     1.0     1     0.0      0.0    5.0            NaN
# 140           0.0     1.0     1     0.0      0.0    5.0            NaN
# 186           0.0     1.0     2     0.0      0.0    5.0            NaN
# 251           0.0     1.0     2     0.0      0.0    5.0            NaN
# ...           ...     ...   ...     ...      ...    ...            ...
# 67091752  38871.0     0.0     8     1.0      0.0    5.0            NaN
# 67091753  38871.0     0.0     8     1.0      0.0    5.0            NaN
# 67091755  38871.0     0.0     8     1.0      0.0    5.0            NaN
# 67091768  38871.0     0.0     8     1.0      0.0    5.0            NaN
# 67091772  38871.0     0.0     8     1.0      0.0    5.0            NaN
#
# [10051180 rows x 7 columns]

# %% [markdown]
# ## test group event_contents 확인

# %%
t_gcg = test.loc[test['event']==5,'event_contents'].value_counts()
t_gcg[:30]
# Out:
# Target: None [00A80001]; Location: (18.0, 147.5, 49120)                              11684
# Target: None [00040001]; Location: (29.0, 15.5, 49104)                               10969
# Target: DestructibleSignsConstruction [00740001]; Location: (20.0, 128.5, 49136)     10511
# Target: DestructibleSignsConstruction [00280001]; Location: (163.0, 15.5, 49088)      9441
# Target: DestructibleSignsConstruction [02600001]; Location: (20.0, 137.5, 49136)      8845
# Target: DestructibleSignsConstruction [02580001]; Location: (157.0, 142.5, 49120)     8725
# Target: None [025C0001]; Location: (144.0, 18.5, 49120)                               8592
# Target: None [016C0001]; Location: (150.0, 24.5, 49120)                               8505
# Target: DestructibleSignsConstruction [000C0001]; Location: (33.0, 19.5, 49120)       8478
# Target: None [00B00001]; Location: (24.0, 153.5, 49120)                               8306
# ...

# %%
len(t_gcg)
# Out:
# 3935433
